# %%
import pandas as pd

# %%
df = pd.read_csv("titanic-publicleaderboard-2026-08-14T03:23:41 2.csv")
print(df)
# Out:
#         Rank    TeamId                                        TeamName  \
# 0          1   2556751                                          Hairet
# 1          2  12801551                                  Veniamin_Nelin
# 2          3  16133376                              SC1+2025104944+JJY
# 3          4  12408744  [Deleted] b4b19f85-81fc-49b4-a3fd-5b258a2ef64d
# 4          5  16355510                               Arman Damirchilou
# ...      ...       ...                                             ...
# 10912  10912  16507202                                Kittima Dangsupa
# 10913  10913  16577439                                  Kirill Vasilev
# 10914  10914  16610038                                        ryuji nk
# 10915  10915  16617683                                        momoking
# 10916  10916  16666119                                     MAHDIGH2332
#
#         LastSubmissionDate  Score  SubmissionCount   TeamMemberUserNames
# ...

# %%
print(df.head(6))
print()
print(df.tail(6))
# Out:
#    Rank    TeamId                                        TeamName  \
# 0     1   2556751                                          Hairet
# 1     2  12801551                                  Veniamin_Nelin
# 2     3  16133376                              SC1+2025104944+JJY
# 3     4  12408744  [Deleted] b4b19f85-81fc-49b4-a3fd-5b258a2ef64d
# 4     5  16355510                               Arman Damirchilou
# 5     6   4288623                                         Sas Pav
#
#     LastSubmissionDate  Score  SubmissionCount   TeamMemberUserNames
# 0  2026-06-15 01:27:51    1.0                2               chcsh21
# 1  2026-08-14 03:04:38    1.0              382         veniaminnelin
# 2  2026-06-22 14:57:29    1.0                2             jiang1888
# 3  2026-07-14 15:44:30    1.0               25  del=a51c2dcc1b5b481b
# 4  2026-06-15 11:45:11    1.0                2      armandamirchilou
# 5  2026-08-13 08:39:16    1.0               68                saspav
#
# ...

# %%
print(df.shape)
print(df.columns)
# Out:
# (10917, 7)
# Index(['Rank', 'TeamId', 'TeamName', 'LastSubmissionDate', 'Score',
#        'SubmissionCount', 'TeamMemberUserNames'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10917 entries, 0 to 10916
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 10917 non-null  int64
#  1   TeamId               10917 non-null  int64
#  2   TeamName             10917 non-null  object
#  3   LastSubmissionDate   10917 non-null  object
#  4   Score                10917 non-null  float64
#  5   SubmissionCount      10917 non-null  int64
#  6   TeamMemberUserNames  10917 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 597.1+ KB
# None

# %%
df.describe()
# Out:
#                Rank        TeamId         Score  SubmissionCount
# count  10917.000000  1.091700e+04  10917.000000     10917.000000
# mean    5458.000000  1.608538e+07      0.771763         3.796922
# std     3151.610779  1.976462e+06      0.053808         9.254359
# min        0.000000  4.187500e+04      0.000000         1.000000
# 25%     2729.000000  1.640697e+07      0.765550         1.000000
# 50%     5458.000000  1.649652e+07      0.775110         2.000000
# 75%     8187.000000  1.659688e+07      0.782290         4.000000
# max    10916.000000  1.671968e+07      1.000000       592.000000

# %%
print(df['Score'].value_counts())
print()
print(df['Score'].unique())
print(df['Score'].nunique())
# Out:
# Score
# 0.77511    2672
# 0.76555     724
# 0.77751     664
# 0.77990     576
# 0.78229     558
#            ...
# 0.97129       1
# 0.58133       1
# 0.57655       1
# 0.57416       1
# 0.83971       1
# Name: count, Length: 146, dtype: int64
#
# [1.      0.9976  0.99282 0.99043 0.97129 0.95693 0.95215 0.94976 0.89473
#  0.89234 0.87559 0.86602 0.86363 0.85885 0.85645 0.85406 0.84928 0.83971
#  0.83732 0.83253 0.83014 0.82775 0.82535 0.82296 0.82057 0.81818 0.81578
#  0.81339 0.811   0.80861 0.80622 0.80382 0.80143 0.79904 0.79665 0.79425
#  0.79186 0.78947 0.78708 0.78468 0.78229 0.7799  0.77751 0.77511 0.77272
#  0.77033 0.76794 0.76555 0.76315 0.76076 0.75837 0.75598 0.75358 0.75119
#  0.7488  0.74641 0.74401 0.74162 0.73923 0.73684 0.73444 0.73205 0.72966
#  0.72727 0.72488 0.72248 0.72009 0.7177  0.71531 0.71291 0.71052 0.70813
#  0.70574 0.70334 0.70095 0.69856 0.69617 0.69377 0.69138 0.68899 0.6866
#  0.68181 0.67942 0.67703 0.67464 0.67224 0.66985 0.66746 0.66507 0.66267
# ...

# %%
print(df['TeamName'].value_counts())
print()
print(df['TeamName'].unique())
print(df['TeamName'].nunique())
# Out:
# TeamName
# Hairet                 1
# huangjiahao32          1
# Kirill Andreev #2      1
# satoshi okiba          1
# zhangyihao             1
#                       ..
# irina Salvatore        1
# Davi Baruch            1
# Suyu Wang              1
# Bhargava Badarinath    1
# MAHDIGH2332            1
# Name: count, Length: 10917, dtype: int64
#
# ['Hairet' 'Veniamin_Nelin' 'SC1+2025104944+JJY' ... 'ryuji nk' 'momoking'
#  'MAHDIGH2332']
# 10917
