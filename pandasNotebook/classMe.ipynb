# %%
! pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x106bb23d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pandas/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x106bb2670>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pandas/
# ...

# %%
import pandas as pd

# %%
restaurant_data ={
    'table_no': [12 ,14 ,15],
    'bill_amount': [1250 ,890 ,2400],
    'waiter_name': ['Opbklo','kbklwa','chuhiChuha']
}

df = pd.DataFrame(restaurant_data)
print(df)
print()
print(type(df))
print()
print(df['bill_amount'])
print()
print(type(df['bill_amount']))
# Out:
#    table_no  bill_amount waiter_name
# 0        12         1250      Opbklo
# 1        14          890      kbklwa
# 2        15         2400  chuhiChuha
#
# <class 'pandas.core.frame.DataFrame'>
#
# 0    1250
# 1     890
# 2    2400
# Name: bill_amount, dtype: int64
#
# <class 'pandas.core.series.Series'>

# %%
total_bill = [4700 ,8000 ,1200 ,500]
seriess = pd.Series(total_bill,index=['mon','tue','wed','thu'])
print(seriess)
print()
print(type(seriess))
# Out:
# mon    4700
# tue    8000
# wed    1200
# thu     500
# dtype: int64
#
# <class 'pandas.core.series.Series'>

# %%
total_order = [45 ,30 ,15 ,60]
seriess = pd.Series(total_order,index=['Pizza','Burger','Pasta','Fries'])
print(seriess)
# Out:
# Pizza     45
# Burger    30
# Pasta     15
# Fries     60
# dtype: int64

# %%
app = {
    'Brand': ['Nike','Puma','Campus'],
    'Price': [3200 ,2799 ,1299],
    'In_Stock': ['Yes','Yes','No']
}
data = pd.DataFrame(app)
print(data)
# Out:
#     Brand  Price In_Stock
# 0    Nike   3200      Yes
# 1    Puma   2799      Yes
# 2  Campus   1299       No

# %%
df = pd.read_csv("tip.csv")
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(df.head(6))
print()
print(df.tail(6))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
#
#      total_bill   tip     sex smoker   day    time  size
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
print(df.shape)
print(df.columns)
# Out:
# (244, 7)
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
